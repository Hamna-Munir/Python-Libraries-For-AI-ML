# %% [markdown]
# # Day 01 – NumPy Practice (5 Questions)
# Basic intro-level NumPy practice with outputs.

# %%
import numpy as np

# Q1: Create a 1D array of numbers 1 to 5
arr = np.array([1, 2, 3, 4, 5])
arr
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

# Q2: Create an array of zeros with length 4
zeros_arr = np.zeros(4)
zeros_arr
# Out:
# array([0., 0., 0., 0.])

# %%
import numpy as np

# Q3: Create an array of ones with shape (2,3)
ones_arr = np.ones((2,3))
ones_arr
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
import numpy as np

# Q4: Generate a random integer between 1 and 10
rand_num = np.random.randint(1, 11)
rand_num
# Out:
# 5  # (Random Example)

# %%
import numpy as np

# Q5: Find mean of array [10, 20, 30, 40]
arr2 = np.array([10,20,30,40])
arr2.mean()
# Out:
# 25.0
