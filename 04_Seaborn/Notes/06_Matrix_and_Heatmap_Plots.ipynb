# %% [markdown]
# # 📂 06 – Matrix and Heatmap Plots in Seaborn
# **Author:** Hamna Munir
# **Repository:** Python-Libraries-for-AI-ML
# **Topic:** Seaborn Heatmaps, Correlation Maps, and Clustermaps
#
# ---
# Matrix plots help visualize **relationships between variables**, especially in high-dimensional datasets.
# Heatmaps and clustermaps are popular for correlation analysis and pattern recognition.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load sample dataset
flights = sns.load_dataset("flights").pivot(index="month", columns="year", values="passengers")

# Correlation
corr = flights.corr()

# Display result to verify
print(flights.head())
print(corr.head())
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# year      1949      1950      1951      1952      1953      1954      1955  \
# year
# 1949  1.000000  0.949435  0.944994  0.905623  0.970144  0.911553  0.908190
# 1950  0.949435  1.000000  0.946923  0.957062  0.880477  0.930967  0.949866
# 1951  0.944994  0.946923  1.000000  0.923131  0.939609  0.959165  0.939515
# 1952  0.905623  0.957062  0.923131  1.000000  0.861005  0.942879  0.956044
# 1953  0.970144  0.880477  0.939609  0.861005  1.000000  0.913945  0.884986
#
# year      1956      1957      1958      1959      1960
# year
# 1949  0.940419  0.933350  0.912513  0.901456  0.887272
# 1950  0.938707  0.934320  0.904400  0.927191  0.887417
# 1951  0.946961  0.946232  0.911054  0.947280  0.894268
# 1952  0.960854  0.963146  0.960107  0.962860  0.925008
# 1953  0.929524  0.928578  0.907120  0.902622  0.894288

# %% [markdown]
# # 1️⃣ heatmap()
# The basic heatmap visualizes matrix values using color intensity.
#
# Useful for:
# - Correlations
# - Missing values
# - Numerical matrices

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flights, cmap="YlGnBu")
plt.title("Basic Heatmap – Flight Passengers")
plt.show()

# %% [markdown]
# # 2️⃣ Annotated Heatmap
# You can show numeric values inside the heatmap using `annot=True`.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flights, annot=True, fmt="d", cmap="viridis")
plt.title("Annotated Heatmap – Flight Data")
plt.show()

# %% [markdown]
# # 3️⃣ Correlation Heatmap
# Correlation matrices show how strongly variables relate.
# Values range from **-1 to 1**.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap – Flight Data")
plt.show()

# %% [markdown]
# # 4️⃣ Masking Upper/Lower Triangle
# Correlation matrices are symmetrical — masking avoids duplication.
#
# This mask hides the **upper triangle**.

# %%
mask = np.triu(np.ones_like(corr))  # Upper-triangle mask

plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", mask=mask, center=0)
plt.title("Correlation Heatmap with Upper Triangle Masked")
plt.show()

# %% [markdown]
# # 5️⃣ clustermap()
# Clustermap performs **hierarchical clustering** automatically.
#
# Useful for:
# - Pattern grouping
# - Time series patterns
# - Biological/genomic data analysis
# - Matrix similarity visualization

# %%
sns.clustermap(flights, cmap="mako", standard_scale=1)
plt.title("Clustermap – Flight Passenger Patterns")
plt.show()

# %% [markdown]
# ---
# # ✅ Summary
# - **heatmap()** → visualizes matrix values
# - **annotated heatmap** → displays numeric values
# - **correlation heatmap** → relationship between variables
# - **masked heatmap** → hides duplicate triangle
# - **clustermap()** → hierarchical clustering for patterns
#
# **Heatmaps are essential for high-level insights and EDA!**
